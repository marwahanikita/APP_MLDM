# %% [markdown]
#                  LM THAPAR SCHOOL OF MANAGEMENT
# PYTHON AND MLDM PROJECT ON FINANACIAL SECTOR AND SERVICES IN MUTUAL FUNDS
# Submitted By :                                        Submitted To:
# Sanya Gupta (502204196)                             Mr. Sandeep Goyal
# Nikita Marwaha (502204095)                          Mr. Nitin Arvind Shelke

# %% [markdown]
# # IMPORT LIBRARIES AND READ THE FILE

# %%
import pandas as pd 
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
sns.set(color_codes=True)

# %%
data=pd.read_csv("Mutualfund.csv")
data
# Out:
#                                           Scheme Name         Plan  \
# 0   SBI Contra Fund - Direct Plan - Growth Contra ...  Direct Plan
# 1   SBI Contra Fund - Regular Plan - Growth Contra...      Regular
# 2   Bandhan Tax Advantage (ELSS) Fund - Direct Pla...  Direct Plan
# 3   Bandhan Tax Advantage (ELSS) Fund - Regular Pl...      Regular
# 4     HDFC Tax Saver Fund - Direct Plan - Growth ELSS  Direct Plan
# 5                   HDFC Tax Saver Fund - Growth ELSS      Regular
# 6   Parag Parikh Tax Saver Fund - Direct Plan - Gr...  Direct Plan
# 7   Parag Parikh Tax Saver Fund - Regular Plan - G...      Regular
# 8          Quant Tax Plan - Direct Plan - Growth ELSS  Direct Plan
# 9                        Quant Tax Plan - Growth ELSS      Regular
# 10  HDFC Flexi Cap Fund - Direct Plan - Growth Fle...  Direct Plan
# 11        HDFC Flexi Cap Fund - Growth Flexi Cap Fund      Regular
# 12  JM Flexi Cap Fund - Direct - Growth Flexi Cap ...  Direct Plan
# ...

# %%
data.head()
# Out:
#                                          Scheme Name         Plan  \
# 0  SBI Contra Fund - Direct Plan - Growth Contra ...  Direct Plan
# 1  SBI Contra Fund - Regular Plan - Growth Contra...      Regular
# 2  Bandhan Tax Advantage (ELSS) Fund - Direct Pla...  Direct Plan
# 3  Bandhan Tax Advantage (ELSS) Fund - Regular Pl...      Regular
# 4    HDFC Tax Saver Fund - Direct Plan - Growth ELSS  Direct Plan
#
#   Category Name  Crisil Rank   YTD  2022  2021  2020   2019   2018  2017  \
# 0   Contra Fund            5 -0.01  0.14  0.49  0.31   0.00  -0.14  0.41
# 1   Contra Fund            5 -0.01  0.13  0.48  0.30  -0.01  -0.14  0.40
# 2          ELSS            5 -0.03  0.05  0.48  0.20   0.04  -0.08  0.55
# 3          ELSS            5 -0.03  0.04  0.47  0.19   0.02  -0.09  0.53
# 4          ELSS            5 -0.02  0.11  0.34  0.06   0.04  -0.10  0.40
#
#    2016   2015  2014   2013  2012
# 0  0.02   0.00  0.48  -0.02     -
# 1  0.02  -0.01  0.47  -0.02  0.34
# ...

# %%
d1=data.columns
d1
# Out:
# Index(['Scheme Name', 'Plan', 'Category Name', 'Crisil Rank', 'YTD', '2022',
#        '2021', '2020', '2019', '2018', '2017', '2016', '2015', '2014', '2013',
#        '2012'],
#       dtype='object')

# %% [markdown]
# # BAR PLOT

# %%
plt.bar(data['Plan'],data['2021'],color="green")
plt.bar(data['Plan'],data['2020'],color="lightblue")
# Out:
# <BarContainer object of 48 artists>

# %%
# X=data["Plan"]
Y=data['2022']
plt.bar(X,Y,color="red",width=0.2)
plt.xlabel("X")
plt.ylabel("Y")
plt.title("Scheme Name vs Years")
plt.show()

# %% [markdown]
# # LINE PLOT

# %%
X_values=data["Category Name"]

Y_values=data['2022']
Y1_values=data['2021']
Y2_values=data['2020']
plt.figure(figsize=(10,10))
plt.plot(X_values,Y_values,color='pink')
plt.plot(X_values,Y1_values,color='black')
plt.plot(X_values,Y2_values,color='orange')


plt.xlabel('Category')
plt.ylabel('Years')

plt.title("Mutual funds")

plt.show()

# %%
X_values=data["Scheme Name"]
Y_values=data['2013']

plt.plot(X_values, Y_values,color='brown',marker='*')

plt.xlabel('Plan')
plt.ylabel('2013')
plt.title("Fund Line Plot ")
plt.show()

# %% [markdown]
# # PIE PLOT

# %%
x=data["Crisil Rank"]
y=data['2022']
plt.pie(x,labels=y,autopct="'%.1f'")
plt.title("PIE PLOT ")
plt.axis('equal')
# Out:
# (-1.1000000023492162,
#  1.1000000043920042,
#  -1.1000000032684716,
#  1.1000000012256792)

# %%
x=data['2022']
y=data['Scheme Name']
plt.pie(x,labels=y,autopct="'%.1f'")
plt.title("PIE PLOT ")
plt.axis('equal')
# Out:
# (-1.1001223162896165,
#  1.1000058245852198,
#  -1.1002446225672147,
#  1.1006861390113618)

# %% [markdown]
# # PAIR PLOT

# %%
sns.pairplot(data,hue='Plan',palette=['b', 'plum'])

# %% [markdown]
# # BOXPLOT

# %%
palette = ['plum', 'g']
sns.boxplot(x='2022', y='Plan', data=data , palette = "Set2")
# Out:
# <AxesSubplot:xlabel='2022', ylabel='Plan'>

# %%
sns.boxplot(x='2022', y='Category Name', data=data,palette = "Set3")
# Out:
# <AxesSubplot:xlabel='2022', ylabel='Category Name'>

# %% [markdown]
# # RELATIONAL PLOT

# %%
g=sns.relplot(x='2022', y='Category Name', data=data ,hue="Plan", style="YTD",
palette=['plum','g'])

# %% [markdown]
# # VIOLIN PLOT

# %%
sns.violinplot(x='2022', y='Plan', data=data,palette=['y','g'])
# Out:
# <AxesSubplot:xlabel='2022', ylabel='Plan'>

# %%
sns.violinplot(x='2022', y='Category Name', data=data, palette="Set1")
# Out:
# <AxesSubplot:xlabel='2022', ylabel='Category Name'>

# %% [markdown]
# S# SWARMPLOT

# %%
sns.swarmplot(x='2022', y='Category Name', data=data , palette="Set2")
# Out:
# <AxesSubplot:xlabel='2022', ylabel='Category Name'>
